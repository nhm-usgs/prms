# %%
import xml.dom.minidom as minidom
import xml.etree.ElementTree as xmlET

import pandas as pd
import numpy as np

from future.utils import iteritems
from pyPRMS.prms_helpers import float_to_str

# %%
# Manually generated control file parameters from setup.c
workfile = '/Users/pnorton/Projects/National_Hydrology_Model/documents/PRMS6/prms_vars_raw.txt'
df = pd.read_csv(workfile, sep='\t')

df.head()
# Out:
#      modules        variable dimensions unused1 datatype  \
# 0      basin  dprst_area_max       nhru    nhru     real
# 1      basin   hru_frac_perv       nhru    nhru     real
# 2      basin      hru_imperv       nhru    nhru     real
# 3      basin        hru_perv       nhru    nhru     real
# 4  basin_sum  basin_actet_mo        one       1   double
#
#                                          description             units  \
# 0  Aggregate sum of surface-depression storage ar...             acres
# 1                   Fraction of HRU that is pervious  decimal fraction
# 2                     Area of HRU that is impervious             acres
# 3                       Area of HRU that is pervious             acres
# 4      Monthly basin area-weighted average actual ET            inches
#
#           unused2
# 0  Dprst_area_max
# 1   Hru_frac_perv
# 2      Hru_imperv
# 3        Hru_perv
# 4  Basin_actet_mo

# %% [markdown]
# ### Generate a XML file for parameters

# %%
# <variable name="dprst_area_clos_max">
#     <type>F</type>
#     <units>acres</units>
#     <desc>Aggregate sum of closed ...</desc>
#     <modules>
#         <module>srunoff</module>
#     </modules>
#     <dimensions>
#         <dimension>nhru</dimension>
#     </dimensions>
# </variable>

NHM_DATATYPES = {'I': 'integer', 'F': 'real', 'D': 'double', 'S': 'string'}
inv_map = {vv: kk for kk, vv in iteritems(NHM_DATATYPES)}

params_xml = xmlET.Element('variables')

for index, row in df.iterrows():
#     print(row)
    param_sub = xmlET.SubElement(params_xml, 'variable')
    param_sub.set('name', row['variable'])

    xmlET.SubElement(param_sub, 'type').text = inv_map[row['datatype']]

    xmlET.SubElement(param_sub, 'units').text = row['units']
    xmlET.SubElement(param_sub, 'desc').text = row['description']
            
    modules_sub = xmlET.SubElement(param_sub, 'modules')

    for mm in (row['modules']).split(','):
        xmlET.SubElement(modules_sub, 'module').text = mm
        
    dimensions_sub = xmlET.SubElement(param_sub, 'dimensions')
    
    for ii, dd in enumerate((row['dimensions']).split(',')):
        curr_dim = xmlET.SubElement(dimensions_sub, 'dimension')
        curr_dim.set('name', dd)
        xmlET.SubElement(curr_dim, 'position').text = str(ii+1)

# %%
xmlstr = minidom.parseString(xmlET.tostring(params_xml)).toprettyxml(indent='    ')

with open('/Users/pnorton/tmp/variables.xml', 'w') as ff:
    ff.write(xmlstr)

# %%
df
# Out:
#             modules                 variable dimensions    unused1 datatype  \
# 0           srunoff      dprst_area_clos_max       nhru       nhru     real
# 1             basin           dprst_area_max       nhru       nhru     real
# 2           srunoff      dprst_area_open_max       nhru       nhru     real
# 3             basin            hru_frac_perv       nhru       nhru     real
# 4             basin               hru_imperv       nhru       nhru     real
# 5             basin                 hru_perv       nhru       nhru     real
# 6         basin_sum           basin_actet_mo        one          1   double
# 7         basin_sum          basin_actet_tot        one          1   double
# 8         basin_sum           basin_actet_yr        one          1   double
# 9         basin_sum             basin_cfs_mo        one          1   double
# 10        basin_sum            basin_cfs_tot        one          1   double
# 11        basin_sum             basin_cfs_yr        one          1   double
# 12        basin_sum          basin_gwflow_mo        one          1   double
# 13        basin_sum         basin_gwflow_tot        one          1   double
# 14        basin_sum          basin_gwflow_yr        one          1   double
# 15        basin_sum      basin_intcp_evap_mo        one          1   double
# 16        basin_sum     basin_intcp_evap_tot        one          1   double
# 17        basin_sum      basin_intcp_evap_yr        one          1   double
# 18        basin_sum        basin_max_temp_mo        one          1   double
# 19        basin_sum       basin_max_temp_tot        one          1   double
# 20        basin_sum        basin_max_temp_yr        one          1   double
# 21        basin_sum        basin_min_temp_mo        one          1   double
# 22        basin_sum       basin_min_temp_tot        one          1   double
# 23        basin_sum        basin_min_temp_yr        one          1   double
# 24        basin_sum         basin_net_ppt_mo        one          1   double
# 25        basin_sum         basin_net_ppt_yr        one          1   double
# 26        basin_sum           basin_potet_mo        one          1   double
# 27        basin_sum          basin_potet_tot        one          1   double
# 28        basin_sum           basin_potet_yr        one          1   double
# 29        basin_sum             basin_ppt_mo        one          1   double
# ..              ...                      ...        ...        ...      ...
# 449  water_use_read    external_transfer_tot  nexternal  Nexternal     real
# 450  water_use_read                 gwr_gain       nhru       nhru     real
# 451  water_use_read             gwr_gain_tot       nhru       nhru     real
# 452  water_use_read             gwr_transfer       nhru       nhru     real
# 453  water_use_read         gwr_transfer_tot       nhru       nhru     real
# 454  water_use_read                lake_gain       nhru       nhru     real
# 455  water_use_read            lake_gain_tot       nhru       nhru     real
# 456  water_use_read            lake_transfer       nhru       nhru     real
# 457  water_use_read        lake_transfer_tot       nhru       nhru     real
# 458  water_use_read             segment_gain   nsegment   nsegment     real
# 459  water_use_read         segment_gain_tot   nsegment   nsegment     real
# 460  water_use_read         segment_transfer   nsegment   nsegment     real
# 461  water_use_read     segment_transfer_tot   nsegment   nsegment     real
# 462  water_use_read            soilzone_gain       nhru       nhru     real
# 463  water_use_read        soilzone_gain_tot       nhru       nhru     real
# 464  water_use_read        total_canopy_gain        one          1   double
# 465  water_use_read      total_consumed_gain        one          1   double
# 466  water_use_read         total_dprst_gain        one          1   double
# 467  water_use_read     total_dprst_transfer        one          1   double
# 468  water_use_read      total_external_gain        one          1   double
# 469  water_use_read  total_external_transfer        one          1   double
# 470  water_use_read           total_gwr_gain        one          1   double
# 471  water_use_read       total_gwr_transfer        one          1   double
# 472  water_use_read          total_lake_gain        one          1   double
# 473  water_use_read      total_lake_transfer        one          1   double
# 474  water_use_read       total_segment_gain        one          1   double
# 475  water_use_read   total_segment_transfer        one          1   double
# 476  water_use_read      total_soilzone_gain        one          1   double
# 477  water_use_read          total_transfers        one          1   double
# 478  water_use_read            transfer_rate  nwateruse  nwateruse   double
#
#                                            description             units  \
# 0    Aggregate sum of closed surface-depression sto...             acres
# 1    Aggregate sum of surface-depression storage ar...             acres
# 2    Aggregate sum of open surface-depression stora...             acres
# 3                     Fraction of HRU that is pervious  decimal fraction
# 4                       Area of HRU that is impervious             acres
# 5                         Area of HRU that is pervious             acres
# 6        Monthly basin area-weighted average actual ET            inches
# 7    Total simulation basin area-weighted average a...            inches
# 8         Yearly basin area-weighted average actual ET            inches
# 9           Monthly total streamflow to stream network               cfs
# 10   Total simulation basin area-weighted average s...            inches
# 11           Yearly total streamflow to stream network               cfs
# 12   Monthly basin area-weighted average groundwate...            inches
# 13   Total simulation basin area-weighted average g...            inches
# 14   Yearly basin area-weighted average groundwater...            inches
# 15   Monthly basin area-weighted average intercepti...            inches
# 16   Total simulation basin area-weighted average c...            inches
# 17   Yearly basin area-weighted average canopy evap...            inches
# 18   Monthly basin area-weighted average maximum ai...        temp_units
# 19   Total simulation basin area-weighted average m...        temp_units
# 20   Yearly basin area-weighted average maximum tem...        temp_units
# 21   Monthly basin area-weighted average minimum ai...        temp_units
# 22   Total simulation basin area-weighted average m...        temp_units
# 23   Yearly basin area-weighted average minimum tem...        temp_units
# 24     Monthly area-weighted average net precipitation            inches
# 25   Yearly basin area-weighted average net precipi...            inches
# 26    Monthly basin area-weighted average potential ET            inches
# 27   Total simulation basin area-weighted average p...            inches
# 28     Yearly basin area-weighted average potential ET        temp_units
# 29   Monthly basin area-weighted average precipitation            inches
# ..                                                 ...               ...
# 449  Transfer flow rate from each external source f...               cfs
# 450  Transfer gain to the groundwater reservoir of ...               cfs
# 451  Transfer gain to the groundwater reservoir of ...               cfs
# 452  Transfer flow rate from the groundwater reserv...               cfs
# 453  Transfer flow rate from the groundwater reserv...               cfs
# 454  Transfer gain to each lake HRU for each time step               cfs
# 455  Transfer gain to each lake HRU for the simulation               cfs
# 456  Transfer flow rate from each lake HRU for each...               cfs
# 457  Transfer flow rate from each lake HRU for the ...               cfs
# 458  Transfer gain for each stream segment for each...               cfs
# 459  Transfer gain for each stream segment for the ...               cfs
# 460  Transfer flow rate from each stream segment fo...               cfs
# 461  Transfer flow rate from each stream segment fo...               cfs
# 462  Transfer gain to the capillary reservoir withi...               cfs
# 463  Transfer gain to the capillary reservoir withi...               cfs
# 464  Transfer gains to all canopy reservoirs for ea...               cfs
# 465  Transfer flow rates to all water-use comsumpti...               cfs
# 466  Transfer gains to all surface-depression stora...               cfs
# 467  Transfer flow rates from all surface-depressio...               cfs
# 468  Transfer gains to all external locations for e...               cfs
# 469  Transfer flow rates from all external sources ...               cfs
# 470  Flow to all groundwater reservoirs for each ti...               cfs
# 471  Transfer flow rates from all groundwater reser...               cfs
# 472  Transfer gains to all lake HRUs for each time ...               cfs
# 473  Transfer flow rates from all lake HRUs for eac...               cfs
# 474  Transfer gains to all stream segments for each...               cfs
# 475  Transfer flow rates from all stream segments f...               cfs
# 476  Transfer gains to all capillary reservoirs for...               cfs
# 477  Transfer of all water-use transfers for each t...               cfs
# 478  Transfer of each water-use transfer for each t...               cfs
#
#                      unused2
# 0        Dprst_area_clos_max
# 1             Dprst_area_max
# 2        Dprst_area_open_max
# 3              Hru_frac_perv
# 4                 Hru_imperv
# 5                   Hru_perv
# 6             Basin_actet_mo
# 7            Basin_actet_tot
# 8             Basin_actet_yr
# 9               Basin_cfs_mo
# 10             Basin_cfs_tot
# 11              Basin_cfs_yr
# 12           Basin_gwflow_mo
# 13          Basin_gwflow_tot
# 14           Basin_gwflow_yr
# 15       Basin_intcp_evap_mo
# 16      Basin_intcp_evap_tot
# 17       Basin_intcp_evap_yr
# 18         Basin_max_temp_mo
# 19        Basin_max_temp_tot
# 20         Basin_max_temp_yr
# 21         Basin_min_temp_mo
# 22        Basin_min_temp_tot
# 23         Basin_min_temp_yr
# 24          Basin_net_ppt_mo
# 25          Basin_net_ppt_yr
# 26            Basin_potet_mo
# 27           Basin_potet_tot
# 28            Basin_potet_yr
# 29              Basin_ppt_mo
# ..                       ...
# 449    External_transfer_tot
# 450                 Gwr_gain
# 451             Gwr_gain_tot
# 452             Gwr_transfer
# 453         Gwr_transfer_tot
# 454                Lake_gain
# 455            Lake_gain_tot
# 456            Lake_transfer
# 457        Lake_transfer_tot
# 458             Segment_gain
# 459         Segment_gain_tot
# 460         Segment_transfer
# 461     Segment_transfer_tot
# 462            Soilzone_gain
# 463        Soilzone_gain_tot
# 464        Total_canopy_gain
# 465      Total_consumed_gain
# 466         Total_dprst_gain
# 467     Total_dprst_transfer
# 468      Total_external_gain
# 469  Total_external_transfer
# 470           Total_gwr_gain
# 471       Total_gwr_transfer
# 472          Total_lake_gain
# 473      Total_lake_transfer
# 474       Total_segment_gain
# 475   Total_segment_transfer
# 476      Total_soilzone_gain
# 477          Total_transfers
# 478            Transfer_rate
#
# [479 rows x 8 columns]
