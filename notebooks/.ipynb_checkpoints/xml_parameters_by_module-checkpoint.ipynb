# %%
import xml.dom.minidom as minidom
import xml.etree.ElementTree as xmlET
from future.utils import iteritems

from pyPRMS.prms_helpers import read_xml

# %%
parent_modules = {'potet': ['potet_hamon', 'potet_hs', 'potet_jh', 'potet_pan', 'potet_pm', 'potet_pm_sta', 'potet_pt', 'potet_hru'],
                  'solar_radiation': ['ccsolrad', 'ddsolrad', 'solar_radiation_hru'], #??soltab??
                  'streamflow': ['muskingum', 'muskingum_lake', 'strmflow_in_out'], 
                  'temperature': ['temp_lsta_laps', 'temp_dist2', 'temperature_hru'],
                  'precipitation': ['precip_1sta_laps', 'precip_dist2', 'precipitation_hru'],
                  'transpiration': ['transp_frost', 'transp_tindex']}

# %%
# Read in the parameters.xml file
global_params_file = '/Users/pnorton/tmp/parameters.xml'
params_root = read_xml(global_params_file)

module_dict = {}
dims_by_param = {}

# Populate parameterSet with all available parameter names
for param in params_root.findall('parameter'):
    xml_param_name = param.attrib.get('name')

    # Build dictionary of dimensions (in correct order) for each parameter
    for cdim in param.findall('./dimensions/dimension'):
        dim_name = cdim.attrib.get('name')
        dim_pos = int(cdim.find('position').text)
        dims_by_param.setdefault(xml_param_name, []).insert(dim_pos, dim_name)    
    
    mods_list = []
    for cmod in param.findall('./modules/module'):
        mods_list.append(cmod.text)
    
    in_parent = False
    
    # If a parameter is required by all the child modules of a parent then add
    # only the parent module to the dictionary.
    for pp, tt in iteritems(parent_modules):
        if len(set(tt).difference(set(mods_list))) == 0:
            module_dict.setdefault(pp, []).append(xml_param_name)
            in_parent = True
            
            # There could be other child modules remaining so add them too
            for mm in set(tt).symmetric_difference(set(mods_list)):
                module_dict_setdefault(mm, []).append(xml_param_name)
                
            break
    
    if not in_parent:
        module_dict.setdefault(cmod.text, []).append(xml_param_name)


        
# for xx, yy in iteritems(module_dict):
#     print(xx)
#     for zz in yy:
#         print('\t{}'.format(zz))
        
for xx, yy in iteritems(dims_by_param):
    print(xx, yy)
# Out:
# ('psta_mon', ['nrain', 'nmonths'])
# ('padj_sn', ['nrain', 'nmonths'])
# ('lapsemax_max', ['nmonths'])
# ('tbl_gate3', ['ngate3'])
# ('tbl_gate2', ['ngate2'])
# ('ccov_intcp', ['nhru', 'nmonths'])
# ('tbl_gate4', ['ngate4'])
# ('width_alpha', ['nsegment'])
# ('tstorm_mo', ['nhru', 'nmonths'])
# ('gw_up_id', ['ncascdgw'])
# ('parent_ssr', ['nhru'])
# ('hru_strmseg_down_id', ['ncascade'])
# ('lat_temp_adj', ['nsegment', 'nmonths'])
# ('va_open_exp', ['nhru'])
# ('tbl_gate', ['ngate'])
# ('nhm_seg', ['nsegment'])
# ('gw_strmseg_down_id', ['ncascdgw'])
# ('hru_up_id', ['ncascade'])
# ('jh_coef_hru', ['nhru'])
# ('snow_mon', ['nhru', 'nmonths'])
# ('nhm_id', ['nhru'])
# ('lapsemin_max', ['nmonths'])
# ('pref_flow_den', ['nhru'])
# ('weir_len', ['nlake'])
# ('snarea_curve', ['ndeplval'])
# ('vdemx', ['nsegment'])
# ('rad_conv', ['one'])
# ('covden_sum', ['nhru'])
# ('hru_percent_imperv', ['nhru'])
# ('soil2gw_max', ['nhru'])
# ('dprst_frac', ['nhru'])
# ('pm_d_coef', ['nhru', 'nmonths'])
# ('hs_krs', ['nhru', 'nmonths'])
# ('rain_code', ['nmonths'])
# ('temp_units', ['one'])
# ('lake_out2', ['nlake'])
# ('basin_tsta', ['one'])
# ('lake_segment_id', ['nsegment'])
# ('potet_cbh_adj', ['nhru', 'nmonths'])
# ('tsta_elev', ['ntemp'])
# ('obsout_lake', ['nlake'])
# ('padj_rn', ['nrain', 'nmonths'])
# ('epan_coef', ['nhru', 'nmonths'])
# ('elev_units', ['one'])
# ('ssstor_init_frac', ['nhru'])
# ('max_tsta', ['one'])
# ('tmax_allrain_offset', ['nhru', 'nmonths'])
# ('lake_din1', ['nlake'])
# ('freeh2o_cap', ['nhru'])
# ('tmin_adj', ['nhru', 'nmonths'])
# ('width_m', ['nsegment'])
# ('dday_slope', ['nhru', 'nmonths'])
# ('mapvars_units', ['one'])
# ('width_flow', ['three'])
# ('print_type', ['one'])
# ('adjmix_rain', ['nhru', 'nmonths'])
# ('rain_cbh_adj', ['nhru', 'nmonths'])
# ('monmax', ['nmonths'])
# ('ccov_slope', ['nhru', 'nmonths'])
# ('segment_type', ['nsegment'])
# ('lake_init', ['nlake'])
# ('psta_ylat', ['nrain'])
# ('smidx_coef', ['nhru'])
# ('rate_table', ['nstage', 'ngate'])
# ('print_freq', ['one'])
# ('crad_coef', ['nhru', 'nmonths'])
# ('rad_trncf', ['nhru'])
# ('o2', ['mxnsos', 'nlake'])
# ('lake_out2_a', ['nlake'])
# ('gwsink_coef', ['nhru'])
# ('cov_type', ['nhru'])
# ('gw_seep_coef', ['nhru'])
# ('lake_evap_adj', ['nmonths', 'nlake'])
# ('tbl_stage', ['nstage'])
# ('subbasin_down', ['nsub'])
# ('hru_lat', ['nhru'])
# ('nsos', ['nlake'])
# ('tmax_index', ['nhru', 'nmonths'])
# ('den_init', ['one'])
# ('obsin_segment', ['nsegment'])
# ('op_flow_thres', ['nhru'])
# ('cecn_coef', ['nhru', 'nmonths'])
# ('precip_units', ['one'])
# ('tsta_ylat', ['ntemp'])
# ('mapvars_freq', ['one'])
# ('seg_winter_humidity', ['nsegment'])
# ('settle_const', ['one'])
# ('maxiter_sntemp', ['one'])
# ('ss_init', ['nsegment'])
# ('ncol', ['one'])
# ('jh_coef', ['nhru', 'nmonths'])
# ('hru_type', ['nhru'])
# ('hru_segment_nhm', ['nhru'])
# ('pmn_mo', ['nrain', 'nmonths'])
# ('vce', ['nsegment'])
# ('hru_y', ['nhru'])
# ('elevlake_init', ['nlake'])
# ('obsout_segment', ['nsegment'])
# ('tmin_lapse', ['nhru', 'nmonths'])
# ('lake_out2_b', ['nlake'])
# ('seg_slope', ['nsegment'])
# ('smidx_exp', ['nhru'])
# ('hru_tsta', ['nhru'])
# ('vcw', ['nsegment'])
# ('gw_down_id', ['ncascdgw'])
# ('dprst_frac_open', ['nhru'])
# ('hru_pct_up', ['ncascade'])
# ('poi_type', ['npoigages'])
# ('radj_wppt', ['nhru'])
# ('azrh', ['nsegment'])
# ('snow_intcp', ['nhru'])
# ('crad_exp', ['nhru', 'nmonths'])
# ('gvr_cell_id', ['nhrucell'])
# ('hru_lon', ['nhru'])
# ('radadj_intcp', ['nhru', 'nmonths'])
# ('parent_hru', ['nhru'])
# ('hamon_coef', ['nhru', 'nmonths'])
# ('snowinfil_max', ['nhru'])
# ('segshade_win', ['nsegment'])
# ('sat_threshold', ['nhru'])
# ('tmax_allsnow', ['nhru', 'nmonths'])
# ('rain_adj', ['nhru', 'nmonths'])
# ('carea_min', ['nhru'])
# ('alte', ['nsegment'])
# ('snow_adj', ['nhru', 'nmonths'])
# ('seg_summer_humidity', ['nsegment'])
# ('dprst_et_coef', ['nhru'])
# ('cascade_flg', ['one'])
# ('circle_switch', ['one'])
# ('ppt_rad_adj', ['nhru', 'nmonths'])
# ('seg_humidity_sta', ['nsegment'])
# ('max_psta', ['one'])
# ('altw', ['nsegment'])
# ('vdwmx', ['nsegment'])
# ('pt_alpha', ['nhru', 'nmonths'])
# ('radmax', ['nhru', 'nmonths'])
# ('soil_rechr_init_frac', ['nhru'])
# ('seg_lat', ['nsegment'])
# ('gw_pct_up', ['ncascdgw'])
# ('irr_type', ['nhru'])
# ('soil_moist_max', ['nhru'])
# ('voe', ['nsegment'])
# ('hru_segment', ['nhru'])
# ('fall_frost', ['nhru'])
# ('slowcoef_lin', ['nhru'])
# ('den_max', ['one'])
# ('tsta_xlong', ['ntemp'])
# ('lake_hru_id', ['nhru'])
# ('K_coef', ['nsegment'])
# ('x_coef', ['nsegment'])
# ('melt_look', ['nhru'])
# ('radj_sppt', ['nhru'])
# ('melt_temp', ['one'])
# ('tosegment', ['nsegment'])
# ('parent_poigages', ['npoigages'])
# ('seg_elev', ['nsegment'])
# ('weir_coef', ['nlake'])
# ('width_values', ['nsegment', 'width_dim'])
# ('snowpack_init', ['nhru'])
# ('carea_max', ['nhru'])
# ('basin_solsta', ['one'])
# ('dprst_depth_avg', ['nhru'])
# ('melt_force', ['nhru'])
# ('sro_to_dprst_imperv', ['nhru'])
# ('hru_ylat', ['nhru'])
# ('gwstor_min', ['nhru'])
# ('dprst_flow_coef', ['nhru'])
# ('hru_elev', ['nhru'])
# ('humidity_percent', ['nhru', 'nmonths'])
# ('psta_elev', ['nrain'])
# ('wrain_intcp', ['nhru'])
# ('soil_moist_init_frac', ['nhru'])
# ('segment_flow_init', ['nsegment'])
# ('hru_tlaps', ['nhru'])
# ('lake_qro', ['nlake'])
# ('crop_coef', ['nhru', 'nmonths'])
# ('outlet_sta', ['one'])
# ('fastcoef_sq', ['nhru'])
# ('ratetbl_lake', ['nratetbl'])
# ('snow_cbh_adj', ['nhru', 'nmonths'])
# ('rain_mon', ['nhru', 'nmonths'])
# ('gwflow_coef', ['nhru'])
# ('gwstor_init', ['nhru'])
# ('pm_n_coef', ['nhru', 'nmonths'])
# ('hru_aspect', ['nhru'])
# ('ssr2gw_exp', ['nhru'])
# ('ss_tau', ['nsegment'])
# ('tmax_cbh_adj', ['nhru', 'nmonths'])
# ('parent_gw', ['nhru'])
# ('hru_windspeed_sta', ['nhru'])
# ('seg_length', ['nsegment'])
# ('tosegment_nhm', ['nsegment', 'nsegment'])
# ('vhw', ['nsegment'])
# ('dprst_frac_init', ['nhru'])
# ('max_missing', ['one'])
# ('lapsemin_min', ['nmonths'])
# ('runoff_units', ['one'])
# ('vow', ['nsegment'])
# ('ssr2gw_rate', ['nhru'])
# ('tmin_cbh_adj', ['nhru', 'nmonths'])
# ('vhe', ['nsegment'])
# ('poi_gage_id', ['npoigages'])
# ('covden_win', ['nhru'])
# ('va_clos_exp', ['nhru'])
# ('dday_intcp', ['nhru', 'nmonths'])
# ('spring_frost', ['nhru'])
# ('gvr_hru_id', ['nhrucell'])
# ('imperv_stor_max', ['nhru'])
# ('lake_type', ['nlake'])
# ('hru_deplcrv', ['nhru'])
# ('lake_vol_init', ['nlake'])
# ('hru_humidity_sta', ['nhru'])
# ('nhm_deplcrv', ['nhru'])
# ('hru_psta', ['nhru'])
# ('psta_xlong', ['nrain'])
# ('cascade_tol', ['one'])
# ('snarea_thresh', ['nhru'])
# ('potet_sublim', ['nhru'])
# ('lake_seep_elev', ['nlake'])
# ('hru_down_id', ['ncascade'])
# ('seg_humidity', ['nsegment', 'nmonths'])
# ('dist_max', ['one'])
# ('lake_coef', ['nlake'])
# ('dprst_seep_rate_open', ['nhru'])
# ('s2', ['mxnsos', 'nlake'])
# ('tbl_stage3', ['nstage3'])
# ('tbl_stage2', ['nstage2'])
# ('tbl_stage4', ['nstage4'])
# ('albedo', ['one'])
# ('slowcoef_sq', ['nhru'])
# ('vdemn', ['nsegment'])
# ('sro_to_dprst_perv', ['nhru'])
# ('hru_pansta', ['nhru'])
# ('frost_temp', ['nhru'])
# ('emis_noppt', ['nhru'])
# ('hru_subbasin', ['nhru'])
# ('srain_intcp', ['nhru'])
# ('tmax_lapse', ['nhru', 'nmonths'])
# ('radadj_slope', ['nhru', 'nmonths'])
# ('vdwan', ['nsegment'])
# ('maxday_prec', ['one'])
# ('monmin', ['nmonths'])
# ('lapsemax_min', ['nmonths'])
# ('hru_slope', ['nhru'])
# ('soil_type', ['nhru'])
# ('rate_table2', ['nstage2', 'ngate2'])
# ('rate_table3', ['nstage3', 'ngate3'])
# ('albset_sna', ['one'])
# ('parent_segment', ['nsegment'])
# ('rate_table4', ['nstage4', 'ngate4'])
# ('albset_rna', ['one'])
# ('tmax_adj', ['nhru', 'nmonths'])
# ('hru_xlong', ['nhru'])
# ('albset_rnm', ['one'])
# ('hru_solsta', ['nhru'])
# ('albset_snm', ['one'])
# ('hru_plaps', ['nhru'])
# ('gw_init', ['nsegment'])
# ('fastcoef_lin', ['nhru'])
# ('elev_outflow', ['nlake'])
# ('dprst_seep_rate_clos', ['nhru'])
# ('transp_tmax', ['nhru'])
# ('segshade_sum', ['nsegment'])
# ('hru_x', ['nhru'])
# ('hru_area', ['nhru'])
# ('soil_rechr_max_frac', ['nhru'])
# ('gvr_cell_pct', ['nhrucell'])
# ('gw_tau', ['nsegment'])
# ('transp_end', ['nhru'])
# ('transp_beg', ['nhru'])
# ('poi_gage_segment', ['npoigages'])

# %% [markdown]
# ### Write parameters into csv format

# %%
import pyPRMS.NhmParamDb_v2 as nhm
import pandas as pd

# %%
workdir = '/Users/pnorton/Projects/National_Hydrology_Model/datasets/bandit/paramdb_v2'

pdb = nhm.NhmParamDb_v2(workdir)

# %%
df = pdb.parameters.get('dday_slope').as_dataframe

# %%
pdb.parameters.get('dday_slope').dimensions.tostructure()
# Out:
# {'nhru': {'position': 0, 'size': 109951},
#  'nmonths': {'position': 1, 'size': 12}}

# %%
# Create a position-ordered list of dimension names for the parameter
dim_list = []

for dm, dd in iteritems(pdb.parameters.get('dday_slope').dimensions.tostructure()):
    dim_list.insert(dd['position'], dm)

print(','.join(dim_list))
# Out:
# nhru,nmonths

# %%
# Write a CSV file of parameter data with the dimension names as a first-line comment

fhdl = open('dday_slope.csv', 'w')

# Write the dimension info as first line
fhdl.write('# {}\n'.format(','.join(dim_list)))

# Write the data to a csv file
df.index += 1
df.to_csv(fhdl, header=False, index=True)

fhdl.close()
